# %%
#importing the packages i will be using for the analysis
#import Pandas
import  pandas as pd

#import Numpy
import numpy as np

# Import matplotlib
import matplotlib.pyplot as plt

# Set plot space as inline for inline plots and qt for external plots
# %matplotlib inline

#import seaborn
import seaborn as sns
import ast

# %%
movie_gross_df=pd.read_csv('bom.movie_gross.csv', index_col = 0)
movie_gross_df.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
#bom_df.describe(include='all')

# %%
name_basics_df =pd.read_csv('name.basics.csv', index_col = 0)
name_basics_df.head()
# Out:
#                 primary_name  birth_year  death_year  \
# nconst
# nm0061671  Mary Ellen Bauder         NaN         NaN
# nm0061865       Joseph Bauer         NaN         NaN
# nm0062070         Bruce Baum         NaN         NaN
# nm0062195       Axel Baumann         NaN         NaN
# nm0062798        Pete Baxter         NaN         NaN
#
#                                          primary_profession  \
# nconst
# nm0061671         miscellaneous,production_manager,producer
# nm0061865        composer,music_department,sound_department
# nm0062070                        miscellaneous,actor,writer
# nm0062195  camera_department,cinematographer,art_department
# nm0062798  production_designer,art_department,set_decorator
#
#                                   known_for_titles
# nconst
# nm0061671  tt0837562,tt2398241,tt0844471,tt0118553
# nm0061865  tt0896534,tt6791238,tt0287072,tt1682940
# nm0062070  tt1470654,tt0363631,tt0104030,tt0102898
# ...

# %%
title_akas_df =pd.read_csv('title.akas.csv', index_col = 0)
title_akas_df.head()
# Out:
#            ordering                                    title region language  \
# title_id
# tt0369610        10                            Джурасик свят     BG       bg
# tt0369610        11                        Jurashikku warudo     JP      NaN
# tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR      NaN
# tt0369610        13                  O Mundo dos Dinossauros     BR      NaN
# tt0369610        14                           Jurassic World     FR      NaN
#
#                  types   attributes  is_original_title
# title_id
# tt0369610          NaN          NaN                0.0
# tt0369610  imdbDisplay          NaN                0.0
# tt0369610  imdbDisplay          NaN                0.0
# tt0369610          NaN  short title                0.0
# tt0369610  imdbDisplay          NaN                0.0

# %%
title_basics_df =pd.read_csv('title.basics.csv', index_col = 0)
title_basics_df
# Out:
#                                          primary_title  \
# tconst
# tt0063540                                    Sunghursh
# tt0066787              One Day Before the Rainy Season
# tt0069049                   The Other Side of the Wind
# tt0069204                              Sabse Bada Sukh
# tt0100275                     The Wandering Soap Opera
# ...                                                ...
# tt9916538                          Kuambil Lagi Hatiku
# tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# tt9916706                              Dankyavar Danka
# tt9916730                                       6 Gunn
# tt9916754               Chico Albuquerque - Revelações
#
#                                         original_title  start_year  \
# tconst
# tt0063540                                    Sunghursh        2013
# tt0066787                              Ashad Ka Ek Din        2019
# tt0069049                   The Other Side of the Wind        2018
# ...

# %%
tmdb_movies_df =pd.read_csv('tmdb.movies.csv', index_col = 0)
tmdb_movies_df
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %%
movie_budgets_df =pd.read_csv('tn.movie_budgets.csv', index_col = 0)
movie_budgets_df
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 78  Dec 31, 2018                                       Red 11
# 79   Apr 2, 1999                                    Following
# 80  Jul 13, 2005                Return to the Land of Wonders
# 81  Sep 29, 2015                         A Plague So Pleasant
# 82   Aug 5, 2005                            My Date With Drew
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# ...

# %%
title_ratings_df =pd.read_csv('title.ratings.csv', index_col = 0)
title_ratings_df.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
#title_ratings_df.info()

# %%
movie_info_df =pd.read_table('rt.movie_info.tsv', index_col = 0)
movie_info_df.head()
# Out:
#                                              synopsis rating  \
# id
# 1   This gritty, fast-paced, and innovative police...      R
# 3   New York City, not-too-distant-future: Eric Pa...      R
# 5   Illeana Douglas delivers a superb performance ...      R
# 6   Michael Douglas runs afoul of a treacherous su...      R
# 7                                                 NaN     NR
#
#                                   genre          director  \
# id
# 1   Action and Adventure|Classics|Drama  William Friedkin
# 3     Drama|Science Fiction and Fantasy  David Cronenberg
# 5     Drama|Musical and Performing Arts    Allison Anders
# 6            Drama|Mystery and Suspense    Barry Levinson
# 7                         Drama|Romance    Rodney Bennett
#
#                              writer  theater_date      dvd_date currency  \
# id
# 1                    Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 3      David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
reviews_df =pd.read_table('rt.reviews.tsv', encoding='unicode_escape',index_col = 0)
reviews_df.head()
# Out:
#                                                review rating   fresh  \
# id
# 3   A distinctly gallows take on contemporary fina...    3/5   fresh
# 3   It's an allegory in search of a meaning that n...    NaN  rotten
# 3   ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   Continuing along a line introduced in last yea...    NaN   fresh
# 3              ... a perverse twist on neorealism...     NaN   fresh
#
#             critic  top_critic         publisher               date
# id
# 3       PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 3   Annalee Newitz           0           io9.com       May 23, 2018
# 3     Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3    Daniel Kasman           0              MUBI  November 16, 2017
# 3              NaN           0      Cinema Scope   October 12, 2017

# %%
#reviews_df.info()

# %%
title_crew_df =pd.read_csv('title.crew.csv', index_col = 0)
title_crew_df.head()
# Out:
#                                directors              writers
# tconst
# tt0285252                      nm0899854            nm0899854
# tt0438973                            NaN  nm0175726,nm1802864
# tt0462036                      nm1940585            nm1940585
# tt0835418                      nm0151540  nm0310087,nm0841532
# tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
title_principals_df =pd.read_csv('title.principals.csv', index_col = 0)
title_principals_df.head()
# Out:
#            ordering     nconst  category       job        characters
# tconst
# tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# tt0111414         2  nm0398271  director       NaN               NaN
# tt0111414         3  nm3739909  producer  producer               NaN
# tt0323808        10  nm0059247    editor       NaN               NaN
# tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %% [markdown]
# printing information about each DataFrame using the info() method and zip() function
#
# to iterate over both the DataFrames and their corresponding names simultaneously.

# %%
#printing information about each DataFrame using the info() method and zip() function to iterate over both the DataFrames and their corresponding names simultaneously.

datasets_dfs = [movie_gross_df, title_principals_df,title_crew_df,reviews_df,movie_info_df,
                title_ratings_df,movie_budgets_df,tmdb_movies_df,title_basics_df,name_basics_df,title_akas_df]
df_names = ['movie_gross', 'title_principals', 'title_crew','reviews','movie_info','title_ratings',
            'movie_budgets','tmdb_movies','title_basics', 'name_basics', 'title_akas']
for df, name in zip(datasets_dfs, df_names):
    print(name, '\n')
    display(df.info())
# Out:
# movie_gross
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB
# None
# title_principals
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1028186 entries, tt0111414 to tt9692684
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   ordering    1028186 non-null  int64
#  1   nconst      1028186 non-null  object
#  2   category    1028186 non-null  object
#  3   job         177684 non-null   object
#  4   characters  393360 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 47.1+ MB
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
#Change production_budget, domestic_gross and worldwide_gross to float64
#Remove dollar sign and commas before changing data type

movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].str.replace('$', '')
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].str.replace('$', '')
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].str.replace('$', '')

movie_budgets_df['production_budget'].replace(',', '', regex=True, inplace=True)
movie_budgets_df['domestic_gross'].replace(',', '', regex=True, inplace=True)
movie_budgets_df['worldwide_gross'].replace(',', '', regex=True, inplace=True)

movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].astype('float64')
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].astype('float64')
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].astype('float64')

# %%
movie_budgets_df.drop_duplicates(subset=['movie', 'release_date'], keep='first', inplace=True)
-movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   float64
#  3   domestic_gross     5782 non-null   float64
#  4   worldwide_gross    5782 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 271.0+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-44a90f6ee893> in <module>
#       1 movie_budgets_df.drop_duplicates(subset=['movie', 'release_date'], keep='first', inplace=True)
# ----> 2 -movie_budgets_df.info()
#
# TypeError: bad operand type for unary -: 'NoneType'

# %%
title_akas_df.drop(['language', 'attributes', 'types'], axis=1, inplace=True)
title_akas_df.head(2)

# %%
name_basics_df.drop(['birth_year','death_year'], axis=1, inplace=True)
name_basics_df.head(2)

# %% [markdown]
# MERGING DATA FRAMES

# %%
movies_df = pd.merge(pd.merge(pd.merge(title_basics_df,title_ratings_df,on="tconst"),
                          title_principals_df,on="tconst"),
                     name_basics_df,on="nconst")
movies_df
# Out:
#                      primary_title              original_title  start_year  \
# 0                        Sunghursh                   Sunghursh        2013
# 1                        Sunghursh                   Sunghursh        2013
# 2                        Sunghursh                   Sunghursh        2013
# 3                        Sunghursh                   Sunghursh        2013
# 4                        Sunghursh                   Sunghursh        2013
# ...                            ...                         ...         ...
# 629593  La vida sense la Sara Amat  La vida sense la Sara Amat        2019
# 629594  La vida sense la Sara Amat  La vida sense la Sara Amat        2019
# 629595                  Drømmeland                  Drømmeland        2019
# 629596                  Drømmeland                  Drømmeland        2019
# 629597                  Drømmeland                  Drømmeland        2019
#
# ...

# %%
ratings_df=title_ratings_df.merge(title_crew_df, left_on='tconst', right_on='tconst', how='inner')

# %%
ratings_df
# Out:
#             averagerating  numvotes            directors  \
# tconst
# tt10356526            8.3        31            nm8353804
# tt10384606            8.9       559  nm9932562,nm9250842
# tt1042974             6.4        20            nm1915232
# tt1043726             4.2     50352            nm0001317
# tt1060240             6.5        21            nm1926349
# ...                   ...       ...                  ...
# tt9805820             8.1        25            nm3828616
# tt9844256             7.5        24            nm0849465
# tt9851050             4.7        14            nm1272773
# tt9886934             7.0         5            nm0001206
# tt9894098             6.3       128           nm10529107
#
#                                             writers
# tconst
# tt10356526                      nm3057599,nm4179342
# tt10384606                                      NaN
# tt1042974                                 nm1915232
# ...

# %%
ratings_basics_df= title_basics_df.merge(ratings_df, left_on='tconst', right_on='tconst', how='inner')
ratings_basics_df
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...                                    ...                         ...
# tt9913084                 Diabolik sono io            Diabolik sono io
# tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# tt9914642                        Albatross                   Albatross
# tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# tt9916160                       Drømmeland                  Drømmeland
#
#            start_year  runtime_minutes                genres  averagerating  \
# tconst
# ...

# %%
title_ratings_basics_df= ratings_basics_df.merge(title_principals_df, left_on='tconst', right_on='tconst', how='inner')
title_ratings_basics_df.head(2)
# Out:
#           primary_title original_title  start_year  runtime_minutes  \
# tconst
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                        genres  averagerating  numvotes  directors  \
# tconst
# tt0063540  Action,Crime,Drama            7.0        77  nm0712540
# tt0063540  Action,Crime,Drama            7.0        77  nm0712540
#
#                                            writers  ordering     nconst  \
# tconst
# tt0063540  nm0023551,nm1194313,nm0347899,nm1391276        10  nm0006210
# tt0063540  nm0023551,nm1194313,nm0347899,nm1391276         1  nm0474801
#
#            category  job                       characters
# tconst
# tt0063540  composer  NaN                              NaN
# tt0063540     actor  NaN  ["Kundan S. Prasad","Bajrangi"]

# %%
title_ratings_basics_df.reset_index(level='tconst')
title_ratings_basics_df.head(2)
# Out:
#           primary_title original_title  start_year  runtime_minutes  \
# tconst
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                        genres  averagerating  numvotes  directors  \
# tconst
# tt0063540  Action,Crime,Drama            7.0        77  nm0712540
# tt0063540  Action,Crime,Drama            7.0        77  nm0712540
#
#                                            writers  ordering     nconst  \
# tconst
# tt0063540  nm0023551,nm1194313,nm0347899,nm1391276        10  nm0006210
# tt0063540  nm0023551,nm1194313,nm0347899,nm1391276         1  nm0474801
#
#            category  job                       characters
# tconst
# tt0063540  composer  NaN                              NaN
# tt0063540     actor  NaN  ["Kundan S. Prasad","Bajrangi"]

# %%
merged_df = pd.merge(title_ratings_basics_df, name_basics_df[['primary_name', 'nconst']], on='nconst', how='left')
merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-460e5d85faf5> in <module>
# ----> 1 merged_df = pd.merge(title_ratings_basics_df, name_basics_df[['primary_name', 'nconst']], on='nconst', how='left')
#       2 merged_df
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
tmdb_movies_budgets_df=tmdb_movies_df.merge(movie_budgets_df, left_on='original_title', right_on='movie', how='inner')
tmdb_movies_budgets_df

# %% [markdown]
# DATA ANALYSIS OF MERGED DATA FRAMES

# %% [markdown]
# tmdb_movies_budgets_df

# %%
descriptive_stats = tmdb_movies_budgets_df[['popularity', 'vote_average', 'vote_count', 'production_budget',
                                            'domestic_gross', 'worldwide_gross']].describe()

print(descriptive_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9acf63c2a4bc> in <module>
# ----> 1 descriptive_stats = tmdb_movies_budgets_df[['popularity', 'vote_average', 'vote_count', 'production_budget',
#       2                                             'domestic_gross', 'worldwide_gross']].describe()
#       3
#       4 print(descriptive_stats)
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
tmdb_movies_budget_df = pd.DataFrame({
    'genre_ids': ["[12, 14, 10751]", "[14, 12, 16, 10751]", "[12, 28, 878]", "[16, 35, 10751]", "[28, 878, 12]"]
})

# Count the occurrences of each genre
genres_count = {}
for genres_list in tmdb_movies_budgets_df['genre_ids']:
    genres_list = ast.literal_eval(genres_list)  # Convert string representation of list to a Python list
    for genre_id in genres_list:
        if genre_id in genres_count:
            genres_count[genre_id] += 1
        else:
            genres_count[genre_id] = 1

# Creating a DataFrame for plotting
genres_df = pd.DataFrame(list(genres_count.items()), columns=['Genre ID', 'Count'])

# Genre mapping for genre names
genre_mapping = {
    12: 'Adventure',
    14: 'Fantasy',
    10751: 'Family',
    16: 'Animation',
    28: 'Action',
    878: 'Science Fiction',
    35: 'Comedy',
    53: 'Thriller',
    27: 'Horror',
    18: 'Drama'
}

# Adding genre names to the DataFrame
genres_df['Genre Name'] = genres_df['Genre ID'].map(genre_mapping)

plt.figure(figsize=(15, 6))
# Sorting by count in ascending order
genres_df.sort_values('Count', ascending=True, inplace=True)

# Plotting using Seaborn
sns.set(style='whitegrid')
sns.barplot(x='Count', y='Genre Name', data=genres_df)

# Display the plot
plt.xlabel('Count')
plt.ylabel('Genre')
plt.title('Distribution of Genres')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d779d4845b71> in <module>
#       5 # Count the occurrences of each genre
#       6 genres_count = {}
# ----> 7 for genres_list in tmdb_movies_budgets_df['genre_ids']:
#       8     genres_list = ast.literal_eval(genres_list)  # Convert string representation of list to a Python list
#       9     for genre_id in genres_list:
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
# Create a new DataFrame with only the 'production_budget' and 'domestic_gross' columns
budget_domestic_df = tmdb_movies_budgets_df[['production_budget', 'domestic_gross']]

# Dropping rows with missing data (if any)
budget_domestic_df = budget_domestic_df.dropna()

# Convert the columns to numeric types
budget_domestic_df['production_budget'] = pd.to_numeric(budget_domestic_df['production_budget'].str.replace('[^\d.]', ''), errors='coerce')
budget_domestic_df['domestic_gross'] = pd.to_numeric(budget_domestic_df['domestic_gross'].str.replace('[^\d.]', ''), errors='coerce')

# Drop any rows where the conversion resulted in NaN (not-a-number)
budget_domestic_df = budget_domestic_df.dropna()

# Calculating the correlation coefficient
correlation_coefficient = budget_domestic_df['production_budget'].corr(budget_domestic_df['domestic_gross'])

print("Correlation coefficient between production budget and domestic gross:", correlation_coefficient)

# Visualizing the relationship with a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(budget_domestic_df['production_budget'], budget_domestic_df['domestic_gross'], alpha=0.5)
plt.xlabel('Production Budget')
plt.ylabel('Domestic Gross')
plt.title('Correlation between Production Budget and Domestic Gross')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-9d6034ba0692> in <module>
#       1 # Create a new DataFrame with only the 'production_budget' and 'domestic_gross' columns
# ----> 2 budget_domestic_df = tmdb_movies_budgets_df[['production_budget', 'domestic_gross']]
#       3
#       4 # Dropping rows with missing data (if any)
#       5 budget_domestic_df = budget_domestic_df.dropna()
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
# Selecting relevant columns for analysis
budget_worldwide_df = tmdb_movies_budgets_df[['production_budget', 'worldwide_gross']]

# Dropping rows with missing data (if any)
budget_worldwide_df = budget_worldwide_df.dropna()

# Calculating the correlation coefficient
correlation_coefficient = budget_worldwide_df['production_budget'].corr(budget_worldwide_df['worldwide_gross'])

print("Correlation coefficient between production budget and worldwide gross:", correlation_coefficient)

# Visualizing the relationship with a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(budget_worldwide_df['production_budget'], budget_worldwide_df['worldwide_gross'], alpha=0.5)
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.title('Correlation between Production Budget and Worldwide Gross')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-224393f5d6c6> in <module>
#       1 # Selecting relevant columns for analysis
# ----> 2 budget_worldwide_df = tmdb_movies_budgets_df[['production_budget', 'worldwide_gross']]
#       3
#       4 # Dropping rows with missing data (if any)
#       5 budget_worldwide_df = budget_worldwide_df.dropna()
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %% [markdown]
# Positive Correlation: The positive sign indicates that there is a positive relationship between the two variables. As the production budget increases, the domestic gross tends to increase as well. This suggests that movies with higher production budgets are more likely to generate higher domestic grosses at the box office. Like the domestic gross the positive sign indicates a positive relationship between the production budget and the worldwide gross which tends to increase as when production budget increases. This implies that movies with higher production budgets are more likely to generate higher worldwide grosses at the box office.
#
# The strong positive correlation between production budget and worldwide gross can be seen as an opportunity for microsoft movie studios. Allocating larger budgets to movies with higher potential can lead to increased worldwide grosses and better returns on investment.While a strong correlation indicates a robust relationship between the variables, it does not mean that one variable directly causes the other to change. Additional analysis and consideration of various factors are necessary to make informed decisions in the film industry.

# %% [markdown]
# Language Analysis: Explore the performance of movies based on their original language,
#     considering metrics such as popularity, vote_average, and vote_count.

# %%
# Group the merged DataFrame by the relevant columns (e.g., 'genre_ids', 'release_year', 'production_budget')
grouped_by_genre = tmdb_movies_budgets_df.groupby('genre_ids')
grouped_by_year = tmdb_movies_budgets_df.groupby('release_date_x')
grouped_by_budget = tmdb_movies_budgets_df.groupby('production_budget')

# Calculate relevant metrics for each group
# Example: average popularity, vote_average, vote_count, revenue-to-budget ratio, etc.
genre_stats = grouped_by_genre[['popularity', 'vote_average', 'vote_count']].mean()
year_stats = grouped_by_year[['popularity', 'vote_average', 'vote_count']].mean()
budget_stats = grouped_by_budget[['popularity', 'vote_average', 'vote_count']].mean()

# Example: Line plot for average vote_average over the years
year_stats['vote_average'].plot(kind='line', figsize=(20, 10))
plt.xlabel('Release Year')
plt.ylabel('Average Vote Average')
plt.title('Average Vote Average over the Years')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e54731a84d96> in <module>
#       1 # Group the merged DataFrame by the relevant columns (e.g., 'genre_ids', 'release_year', 'production_budget')
# ----> 2 grouped_by_genre = tmdb_movies_budgets_df.groupby('genre_ids')
#       3 grouped_by_year = tmdb_movies_budgets_df.groupby('release_date_x')
#       4 grouped_by_budget = tmdb_movies_budgets_df.groupby('production_budget')
#       5
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
# Group the tmdb_movies_budgets_df  by 'original_language'
language_grouped = tmdb_movies_budgets_df.groupby('original_language')

# Calculate the average popularity, vote_average, and vote_count for each language group
language_stats = language_grouped[['popularity', 'vote_average', 'vote_count']].mean()

# Sort the DataFrame by average popularity to find the most popular languages
language_stats = language_stats.sort_values(by='popularity', ascending=True)

# Plot the language analysis results
fig, axes = plt.subplots(3, 1, figsize=(10, 15))
language_stats['popularity'].plot(kind='bar', ax=axes[0], color='b', alpha=0.7)
axes[0].set_ylabel('Average Popularity')
axes[0].set_title('Average Popularity by Original Language')

language_stats['vote_average'].plot(kind='bar', ax=axes[1], color='g', alpha=0.7)
axes[1].set_ylabel('Average Vote Average')
axes[1].set_title('Average Vote Average by Original Language')

language_stats['vote_count'].plot(kind='bar', ax=axes[2], color='r', alpha=0.7)
axes[2].set_ylabel('Average Vote Count')
axes[2].set_title('Average Vote Count by Original Language')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-bb6ac0727ce4> in <module>
#       1 # Group the tmdb_movies_budgets_df  by 'original_language'
# ----> 2 language_grouped = tmdb_movies_budgets_df.groupby('original_language')
#       3
#       4 # Calculate the average popularity, vote_average, and vote_count for each language group
#       5 language_stats = language_grouped[['popularity', 'vote_average', 'vote_count']].mean()
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
#Create two new columns: gross_profit and profit_margin (Drop any movies with 0 gross revenue)
tmdb_movies_budgets_df['net_profit'] = tmdb_movies_budgets_df['worldwide_gross'] - tmdb_movies_budgets_df['production_budget']
tmdb_movies_budgets_df['profit_margin'] = round(tmdb_movies_budgets_df['net_profit'] / tmdb_movies_budgets_df['worldwide_gross'], 6)
tmdb_movies_budgets_df.profit_margin.replace(-np.inf, np.nan, inplace=True)
tmdb_movies_budgets_df.dropna(inplace=True)
tmdb_movies_budgets_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-4c20fe3bb215> in <module>
#       1 #Create two new columns: gross_profit and profit_margin (Drop any movies with 0 gross revenue)
# ----> 2 tmdb_movies_budgets_df['net_profit'] = tmdb_movies_budgets_df['worldwide_gross'] - tmdb_movies_budgets_df['production_budget']
#       3 tmdb_movies_budgets_df['profit_margin'] = round(tmdb_movies_budgets_df['net_profit'] / tmdb_movies_budgets_df['worldwide_gross'], 6)
#       4 tmdb_movies_budgets_df.profit_margin.replace(-np.inf, np.nan, inplace=True)
#       5 tmdb_movies_budgets_df.dropna(inplace=True)
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
tmdb_movies_budgets_df[tmdb_movies_budgets_df['profit_margin'] == tmdb_movies_budgets_df.profit_margin.min()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-427f11c33dec> in <module>
# ----> 1 tmdb_movies_budgets_df[tmdb_movies_budgets_df['profit_margin'] == tmdb_movies_budgets_df.profit_margin.min()]
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
#Sort by gross_profit to see most successful movies
top_30_net_profit = tmdb_movies_budgets_df.sort_values(by='net_profit', ascending=False)[:30]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a20c5134c0f2> in <module>
#       1 #Sort by gross_profit to see most successful movies
# ----> 2 top_30_net_profit = tmdb_movies_budgets_df.sort_values(by='net_profit', ascending=False)[:30]
#
# NameError: name 'tmdb_movies_budgets_df' is not defined

# %%
plt.figure(figsize=(20, 8))
sns.set(style='whitegrid')

# Plotting the bar chart for net profit
sns.barplot(x='net_profit', y='movie', data=top_30_net_profit,
            label='Average Net Profit: {}'.format(round(top_30_net_profit['net_profit'].mean(), 0)))

# Plotting the bar chart for production budget (overlayed on the net profit bars)
sns.barplot(x='production_budget', y='movie', data=top_30_net_profit, color='blue', alpha=0.5)

plt.xlabel('Amount in USD')
plt.ylabel('Movie')
plt.title('Top 30 Movies by Net Profit and Production Budget')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2004a7d2cf64> in <module>
#       3
#       4 # Plotting the bar chart for net profit
# ----> 5 sns.barplot(x='net_profit', y='movie', data=top_30_net_profit,
#       6             label='Average Net Profit: {}'.format(round(top_30_net_profit['net_profit'].mean(), 0)))
#       7
#
# NameError: name 'top_30_net_profit' is not defined

# %%
title_ratings_basics_df
# Out:
#           primary_title original_title  start_year  runtime_minutes  \
# tconst
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# tt0063540     Sunghursh      Sunghursh        2013            175.0
# ...                 ...            ...         ...              ...
# tt9916160    Drømmeland     Drømmeland        2019             72.0
# tt9916160    Drømmeland     Drømmeland        2019             72.0
# tt9916160    Drømmeland     Drømmeland        2019             72.0
# tt9916160    Drømmeland     Drømmeland        2019             72.0
# tt9916160    Drømmeland     Drømmeland        2019             72.0
#
#                        genres  averagerating  numvotes  directors  \
# tconst
# ...

# %%
genre_counts = title_ratings_basics_df['genres'].str.split(',', expand=True).stack().value_counts()

# Plot the genre distribution
plt.figure(figsize=(15, 6))
genre_counts.plot(kind='bar')
plt.title('Distribution of Movie Genres')
plt.xlabel('Genres')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.show()

# %%
directors_counts = movies_df['directors'].value_counts()

# Plot the director distribution
plt.figure(figsize=(10, 6))
directors_counts.head(20).plot(kind='barh')
plt.title('Top 20 Movie Directors by Movie Count')
plt.xlabel('Number of Movies Directed')
plt.ylabel('Directors')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'directors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-53bf1b234077> in <module>
# ...

# %%
# Runtime Comparison Across Genres
average_runtime_by_genre = movies_df.groupby('genres')['runtime_minutes'].mean()
average_runtime_by_genre.plot(kind='bar', figsize=(20, 10))
plt.xlabel('Genres')
plt.ylabel('Average Runtime (minutes)')
plt.title('Average Runtime Comparison Across Genres')
plt.show()

# Average Rating Over the Years
average_rating_by_year = movies_df.groupby('start_year')['averagerating'].mean()
average_rating_by_year.plot(kind='line', figsize=(20, 10))
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Rating Over the Years')
plt.show()

# Number of Votes Over the Years
votes_by_year = movies_df.groupby('start_year')['numvotes'].sum()
votes_by_year.plot(kind='line', figsize=(20, 10))
plt.xlabel('Year')
plt.ylabel('Number of Votes')
plt.title('Number of Votes Over the Years')
plt.show()

# Runtime Over the Years
average_runtime_by_year = movies_df.groupby('start_year')['runtime_minutes'].mean()
average_runtime_by_year.plot(kind='line', figsize=(20, 10))
plt.xlabel('Year')
plt.ylabel('Average Runtime (minutes)')
plt.title('Average Runtime Over the Years')
plt.show()

# Correlation Between Rating, Votes, and Runtime
corr_matrix = movies_df[['averagerating', 'numvotes', 'runtime_minutes']].corr()
plt.figure(figsize=(8, 6))
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr_matrix)), corr_matrix.columns, rotation=45)
plt.yticks(range(len(corr_matrix)), corr_matrix.columns)
plt.title('Correlation Between Rating, Votes, and Runtime')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-6762d003c23b> in <module>
#       1 # Runtime Comparison Across Genres
# ----> 2 average_runtime_by_genre = movies_df.groupby('genres')['runtime_minutes'].mean()
#       3 average_runtime_by_genre.plot(kind='bar', figsize=(20, 10))
#       4 plt.xlabel('Genres')
#       5 plt.ylabel('Average Runtime (minutes)')
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1391         Name: B, dtype: float64
#    1392         """
# -> 1393         return self._cython_agg_general(
#    1394             "mean",
#    1395             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
# ...

# %%
# Handle NaN values in the 'genres' column by filling them with an empty string ''
movies_df['genres'] = movies_df['genres'].fillna('')

# Split genres into lists (assuming genres are comma-separated)
movies_df['genres'] = movies_df['genres'].apply(lambda x: x.split(',') if x != '' else [])

# Create a new DataFrame with multiple rows for each movie, one for each genre
movies_genre_expanded = movies_df.explode('genres')

# Cross-Genre Analysis - Average Ratings
cross_genre_avg_ratings = movies_genre_expanded.groupby('genres')['averagerating'].mean()
cross_genre_avg_ratings = cross_genre_avg_ratings.reset_index().sort_values(by='averagerating', ascending=False)

# Cross-Genre Analysis - Number of Votes
cross_genre_num_votes = movies_genre_expanded.groupby('genres')['numvotes'].sum()
cross_genre_num_votes = cross_genre_num_votes.reset_index().sort_values(by='numvotes', ascending=False)

# Display top genres with highest average ratings and most number of votes
top_rated_genres = cross_genre_avg_ratings.head(10)
most_voted_genres = cross_genre_num_votes.head(10)

# Plotting top genres with highest average ratings
plt.figure(figsize=(10, 6))
plt.bar(top_rated_genres['genres'], top_rated_genres['averagerating'])
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.title('Top Genres with Highest Average Ratings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plotting top genres with most number of votes
plt.figure(figsize=(10, 6))
plt.bar(most_voted_genres['genres'], most_voted_genres['numvotes'])
plt.xlabel('Genre')
plt.ylabel('Number of Votes')
plt.title('Top Genres with Most Number of Votes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-4b10ed7f26dc> in <module>
#       3
#       4 # Split genres into lists (assuming genres are comma-separated)
# ----> 5 movies_df['genres'] = movies_df['genres'].apply(lambda x: x.split(',') if x != '' else [])
#       6
#       7 # Create a new DataFrame with multiple rows for each movie, one for each genre
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-50-4b10ed7f26dc> in <lambda>(x)
#       3
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the 'movies_df' DataFrame with the required columns

# Crew Analysis - Average Ratings
crew_avg_ratings = movies_df.groupby(['category', 'primary_name'])['averagerating'].mean()
crew_avg_ratings = crew_avg_ratings.reset_index().sort_values(by='averagerating', ascending=False)

# Crew Analysis - Number of Movies
crew_num_movies = movies_df.groupby(['category', 'primary_name']).size()
crew_num_movies = crew_num_movies.reset_index(name='num_movies').sort_values(by='num_movies', ascending=False)

# Display top crew members with highest average ratings and most number of movies
top_rated_crew_members = crew_avg_ratings.head(10)
most_movies_crew_members = crew_num_movies.head(10)

# Plotting top crew members with highest average ratings
plt.figure(figsize=(10, 6))
plt.bar(top_rated_crew_members['primary_name'], top_rated_crew_members['averagerating'])
plt.xlabel('Crew Member')
plt.ylabel('Average Rating')
plt.title('Top Crew Members with Highest Average Ratings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plotting top crew members with most number of movies
plt.figure(figsize=(10, 6))
plt.bar(most_movies_crew_members['primary_name'], most_movies_crew_members['num_movies'])
plt.xlabel('Crew Member')
plt.ylabel('Number of Movies')
plt.title('Top Crew Members with Most Number of Movies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the 'movies_df' DataFrame with the required columns

# Director Analysis - Average Ratings
director_avg_ratings = movies_df[movies_df['category'] == 'director'].groupby('primary_name')['averagerating'].mean()
director_avg_ratings = director_avg_ratings.reset_index().sort_values(by='averagerating', ascending=False)

# Director Analysis - Number of Movies
director_num_movies = movies_df[movies_df['category'] == 'director'].groupby('primary_name').size()
director_num_movies = director_num_movies.reset_index(name='num_movies').sort_values(by='num_movies', ascending=False)

# Display top 20 directors with highest average ratings and most number of movies
top_rated_directors = director_avg_ratings.head(20)
most_movies_directors = director_num_movies.head(20)

# Plotting top 20 directors with highest average ratings
plt.figure(figsize=(10, 6))
plt.bar(top_rated_directors['primary_name'], top_rated_directors['averagerating'])
plt.xlabel('Director')
plt.ylabel('Average Rating')
plt.title('Top 20 Directors with Highest Average Ratings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plotting top 20 directors with most number of movies
plt.figure(figsize=(10, 6))
plt.bar(most_movies_directors['primary_name'], most_movies_directors['num_movies'])
plt.xlabel('Director')
plt.ylabel('Number of Movies')
plt.title('Top 20 Directors with Most Number of Movies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the 'movies_df' DataFrame with the required columns

# Actor Analysis - Average Ratings
actor_avg_ratings = movies_df[movies_df['category'] == 'actor'].groupby('primary_name')['averagerating'].mean()
actor_avg_ratings = actor_avg_ratings.reset_index().sort_values(by='averagerating', ascending=False)

# Actor Analysis - Number of Movies
actor_num_movies = movies_df[movies_df['category'] == 'actor'].groupby('primary_name').size()
actor_num_movies = actor_num_movies.reset_index(name='num_movies').sort_values(by='num_movies', ascending=False)

# Display top 20 actors with highest average ratings and most number of movies
top_rated_actors = actor_avg_ratings.head(20)
most_movies_actors = actor_num_movies.head(20)

# Plotting top 20 actors with highest average ratings
plt.figure(figsize=(10, 6))
plt.bar(top_rated_actors['primary_name'], top_rated_actors['averagerating'])
plt.xlabel('Actor')
plt.ylabel('Average Rating')
plt.title('Top 20 Actors with Highest Average Ratings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plotting top 20 actors with most number of movies
plt.figure(figsize=(10, 6))
plt.bar(most_movies_actors['primary_name'], most_movies_actors['num_movies'])
plt.xlabel('Actor')
plt.ylabel('Number of Movies')
plt.title('Top 20 Actors with Most Number of Movies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the 'movies_df' DataFrame with the required columns

# Calculate basic statistics
mean_rating = movies_df['averagerating'].mean()
median_rating = movies_df['averagerating'].median()
min_rating = movies_df['averagerating'].min()
max_rating = movies_df['averagerating'].max()
std_rating = movies_df['averagerating'].std()




# Explore the distribution of movie ratings, votes, and runtime using histograms
plt.figure(figsize=(20, 6))

plt.subplot(1, 3, 1)
plt.hist(movies_df['averagerating'], bins=20, edgecolor='black')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Ratings')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the 'movies_df' DataFrame with the required columns

# Filter the DataFrame to consider only rows where the 'category' is 'director'
director_movies_df = movies_df[movies_df['category'] == 'director']

# Group by director and count the number of titles for each director
directors_title_count = director_movies_df.groupby('primary_name').size()

# Filter directors with more than one title
directors_multiple_titles = directors_title_count[directors_title_count > 1]

# Display directors with more than one title
print("Directors with More Than One Title:")
print(directors_multiple_titles)

# Plotting the directors with more than one title
plt.figure(figsize=(10, 6))
plt.bar(directors_multiple_titles.index, directors_multiple_titles.values)
plt.xlabel('Director')
plt.ylabel('Number of Titles')
plt.title('Directors with More Than One Title')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
